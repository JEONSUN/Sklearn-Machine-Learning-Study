# %% [markdown]
# ### 군집의 정의와 몇 개의 군집 알고리즘을 말해보세요.

# %% [markdown]
# 비지도 학습중 하나로 레이블이 없는 데이터들을 비슷한 특성별로 모으는 작업을 한다.
#
# k - means 알고리즘, DBSCAN 알고리즘, 가우시안 혼합 모델등이 있다.

# %% [markdown]
# ### 군집 알고리즘의 주요 어플리케이션은?

# %% [markdown]
# 군집 알고리즘의 주요 어플리케이션은 고객 분류, 추천 시스템, 이미지 분할, 차원 축소, 이상치 탐지 등에 사용한다.

# %% [markdown]
# ### k-평균을 사용할 때 적절한 클러스터 개수를 선택할 수 있는 두 가지 기법을 설명하세요.

# %% [markdown]
# **1. 이너셔가 빠르게 감소하지 않는 지점(엘보)**
#
# 이너셔 : 샘플과 클러스터 중심 간 평균 제곱 거리
#
# **2. 실루엣 계수의 평균인 실루엣 점수**
#
# 실루엣 계수 : $(b-a)/max(a,b)$
# <br>a = 동일한 클러스터에 있는 다른 샘플까지 평균 거리 b = 가장 가까운 클러스터까지 평균 거리

# %% [markdown]
# ### 레이블 전파는 무엇일까요? 왜 이를 구현해야 하고 어떻게 구현할 수 있나요?

# %% [markdown]
# 레이블이 있는 샘플 일부를 활용하여 레이블이 없는 비슷한 샘플, 같은 클러스터에 복사하는 기법

# %% [markdown]
# ### 대규모 데이터셋으로 확장할 수 있는 군집 알고리즘 두 개를 말해보세요. 밀도가 높은 지역을 찾는 군집 알고리즘 두 개는 무엇인가요?

# %% [markdown]
# k평균과 BIRCH를 대규모 데이터셋에 적용할 수 있다. DBSCAN과 평균 이동이 밀도가 높은 지역을 찾는다.

# %% [markdown]
# ### 능동 학습이 유용한 경우는 언제인가요? 어떻게 구현할 수 있나요?

# %% [markdown]
# 레이블이 없는 샘플이 많고 레이블을 부여하는 것에 비용이 많이 들때는 능동 학습이 유용하다.
#
# 전문가가 학습 알고리즘과 상호작용하여 알고리즘이 요청하는 특정 샘플에 레이블을 제공한다.

# %% [markdown]
# ###  이상치 탐지와 정상치 탐지의 차이는 무엇일까요?

# %% [markdown]
# 이상치 탐지 : 이상치와 새로운 샘플 사이에 있는 이상치를 구별해내는 것이다.
#
# 특이치 탐지 : 깨끗하다고 가정한 데이터셋에서 알고리즘을 훈련하여 새로운 샘플 사이의 특이한 것을 감지한다.

# %% [markdown]
# ### 가우시안 혼합이 무엇일까요? 어떤 작업에 사용할 수 있나요?

# %% [markdown]
# GMM은 샘플이 파라미터가 알려지지않은 가우시안 분포에서 생성되었다고 가정하는 확률 모델
#
# 밀집도 추정, 군집, 이상치 탐지에 이 모델을 사용할 수 있다.

# %% [markdown]
# ### 문제: 전통적인 올리베티 얼굴 데이터셋은 64×64 픽셀 크기의 흑백 얼굴 이미지 400개를 담고 있습니다. 각 이미지는 4,096 크기의 1D 벡터로 펼쳐져 있습니다. 사람 40명의 사진을 10장씩 찍은 것입니다. 어떤 사람의 사진인지 예측하는 모델을 훈련하는 것이 일반적입니다. sklearn.datasets.fetch_olivetti_faces() 함수를 사용해 데이터셋을 불러오세요.

# %%
from sklearn.datasets import fetch_olivetti_faces
olive = fetch_olivetti_faces()

# %%
len(olive['target'])
# Out:
# 400

# %% [markdown]
# 문제: 데이터셋을 훈련 세트, 검증 세트, 테스트 세트로 나눕니다(이 데이터셋은 이미 0에서 1 사이로 스케일이 조정되어 있습니다). 이 데이터셋은 매우 작으니 계층적 샘플링을 사용해 각 세트에 동일한 사람의 얼굴이 고루 섞이도록 하는 것이 좋습니다.

# %%
# 계층적 샘플링 : StratifiedShuffleSplit
# 데이터 셋 내 층의 비율을 고려하여 층별로 구분하여 무작위로 추출 
# train 70%, test 10%, valid 20%
from sklearn.model_selection import StratifiedShuffleSplit
n_shuffle = StratifiedShuffleSplit(n_splits = 1, test_size = 0.1, random_state = 42)
val_train_idx, test_idx = next(n_shuffle.split(olive.data, olive.target))

# %%
# test 데이터 분리
x_train_valid = olive.data[val_train_idx]
y_train_valid = olive.target[val_train_idx]
x_test = olive.data[test_idx]
y_test = olive.target[test_idx]

# %%
# train 데이터와 valid 데이터 분리
n2_shuffle = StratifiedShuffleSplit(n_splits = 1, test_size = 0.2, random_state = 42)
train_idx, val_idx = next(n2_shuffle.split(x_train_valid, y_train_valid))
x_train = x_train_valid[train_idx]
y_train = y_train_valid[train_idx]
x_valid = x_train_valid[val_idx]
y_valid = y_train_valid[val_idx]

# %%
print(x_train.shape, y_train.shape)
print(x_valid.shape, y_valid.shape)
print(x_test.shape,y_test.shape)
# Out:
# (288, 4096) (288,)
# (72, 4096) (72,)
# (40, 4096) (40,)

# %% [markdown]
# 문제: 그다음 k-평균을 사용해 이미지를 군집해보세요. (이 장에서 소개한 기법 중 하나를 사용해) 적절한 클러스터 개수를 찾아보세요.

# %%
from sklearn.cluster import KMeans
km_per_k = []
for k in range(5,105,5)  :
    print("현재 k = {} 진행중...".format(k))
    km = KMeans(n_clusters = k, random_state = 42).fit(x_train)
    km_per_k.append(km)
    print("<--- k = {} 진행 완료! --->".format(k))
# Out:
# 현재 k = 5 진행중...
# <--- k = 5 진행 완료! --->
# 현재 k = 10 진행중...
# <--- k = 10 진행 완료! --->
# 현재 k = 15 진행중...
# <--- k = 15 진행 완료! --->
# 현재 k = 20 진행중...
# <--- k = 20 진행 완료! --->
# 현재 k = 25 진행중...
# <--- k = 25 진행 완료! --->
# 현재 k = 30 진행중...
# <--- k = 30 진행 완료! --->
# 현재 k = 35 진행중...
# <--- k = 35 진행 완료! --->
# 현재 k = 40 진행중...
# <--- k = 40 진행 완료! --->
# 현재 k = 45 진행중...
# <--- k = 45 진행 완료! --->
# 현재 k = 50 진행중...
# <--- k = 50 진행 완료! --->
# 현재 k = 55 진행중...
# <--- k = 55 진행 완료! --->
# 현재 k = 60 진행중...
# <--- k = 60 진행 완료! --->
# 현재 k = 65 진행중...
# <--- k = 65 진행 완료! --->
# 현재 k = 70 진행중...
# <--- k = 70 진행 완료! --->
# 현재 k = 75 진행중...
# <--- k = 75 진행 완료! --->
# 현재 k = 80 진행중...
# <--- k = 80 진행 완료! --->
# 현재 k = 85 진행중...
# <--- k = 85 진행 완료! --->
# 현재 k = 90 진행중...
# <--- k = 90 진행 완료! --->
# 현재 k = 95 진행중...
# <--- k = 95 진행 완료! --->
# 현재 k = 100 진행중...
# <--- k = 100 진행 완료! --->

# %%
inertias = [model.inertia_ for model in km_per_k]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,6))
plt.plot(range(5,105,5), inertias, "bo-", label = "inertia")
plt.legend()
plt.show()

# %% [markdown]
# #### 클러스터가 늘어날수록 이너셔가 감소함, 클러스터 추가하여 재차 검토

# %%
from sklearn.cluster import KMeans
km_per_k = []
for k in range(50,205,5)  :
    print("현재 k = {} 진행중...".format(k))
    km = KMeans(n_clusters = k, random_state = 42).fit(x_train)
    km_per_k.append(km)
    print("<--- k = {} 진행 완료! --->".format(k))
    
inertias = [model.inertia_ for model in km_per_k]
# Out:
# 현재 k = 50 진행중...
# <--- k = 50 진행 완료! --->
# 현재 k = 55 진행중...
# <--- k = 55 진행 완료! --->
# 현재 k = 60 진행중...
# <--- k = 60 진행 완료! --->
# 현재 k = 65 진행중...
# <--- k = 65 진행 완료! --->
# 현재 k = 70 진행중...
# <--- k = 70 진행 완료! --->
# 현재 k = 75 진행중...
# <--- k = 75 진행 완료! --->
# 현재 k = 80 진행중...
# <--- k = 80 진행 완료! --->
# 현재 k = 85 진행중...
# <--- k = 85 진행 완료! --->
# 현재 k = 90 진행중...
# <--- k = 90 진행 완료! --->
# 현재 k = 95 진행중...
# <--- k = 95 진행 완료! --->
# 현재 k = 100 진행중...
# <--- k = 100 진행 완료! --->
# 현재 k = 105 진행중...
# <--- k = 105 진행 완료! --->
# 현재 k = 110 진행중...
# <--- k = 110 진행 완료! --->
# 현재 k = 115 진행중...
# <--- k = 115 진행 완료! --->
# 현재 k = 120 진행중...
# <--- k = 120 진행 완료! --->
# 현재 k = 125 진행중...
# <--- k = 125 진행 완료! --->
# 현재 k = 130 진행중...
# <--- k = 130 진행 완료! --->
# 현재 k = 135 진행중...
# <--- k = 135 진행 완료! --->
# 현재 k = 140 진행중...
# <--- k = 140 진행 완료! --->
# 현재 k = 145 진행중...
# <--- k = 145 진행 완료! --->
# 현재 k = 150 진행중...
# <--- k = 150 진행 완료! --->
# 현재 k = 155 진행중...
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize = (10,6))
plt.plot(range(50,205,5), inertias, "bo-", label = "inertia")
plt.xlabel('$K$')
plt.legend()
plt.show()

# %% [markdown]
# #### k가 높아질수록 이너셔가 계속해서 낮아짐 -> k를 늘리기보단 pca를 통해 데이터 계산 속도를 늘려봄

# %%
from sklearn.decomposition import PCA

pca = PCA(0.99)
x_train_pca = pca.fit_transform(x_train)
x_valid_pca = pca.fit_transform(x_valid)
x_test_pca = pca.fit_transform(x_test)

pca.n_components_
# Out:
# 36

# %%
from sklearn.cluster import KMeans
km_per_k = []
for k in range(5,155,5)  :
    print("현재 k = {} 진행중...".format(k))
    km = KMeans(n_clusters = k, random_state = 42).fit(x_train_pca)
    km_per_k.append(km)
    print("<--- k = {} 진행 완료! --->".format(k))
# Out:
# 현재 k = 5 진행중...
# <--- k = 5 진행 완료! --->
# 현재 k = 10 진행중...
# <--- k = 10 진행 완료! --->
# 현재 k = 15 진행중...
# <--- k = 15 진행 완료! --->
# 현재 k = 20 진행중...
# <--- k = 20 진행 완료! --->
# 현재 k = 25 진행중...
# <--- k = 25 진행 완료! --->
# 현재 k = 30 진행중...
# <--- k = 30 진행 완료! --->
# 현재 k = 35 진행중...
# <--- k = 35 진행 완료! --->
# 현재 k = 40 진행중...
# <--- k = 40 진행 완료! --->
# 현재 k = 45 진행중...
# <--- k = 45 진행 완료! --->
# 현재 k = 50 진행중...
# <--- k = 50 진행 완료! --->
# 현재 k = 55 진행중...
# <--- k = 55 진행 완료! --->
# 현재 k = 60 진행중...
# <--- k = 60 진행 완료! --->
# 현재 k = 65 진행중...
# <--- k = 65 진행 완료! --->
# 현재 k = 70 진행중...
# <--- k = 70 진행 완료! --->
# 현재 k = 75 진행중...
# <--- k = 75 진행 완료! --->
# 현재 k = 80 진행중...
# <--- k = 80 진행 완료! --->
# 현재 k = 85 진행중...
# <--- k = 85 진행 완료! --->
# 현재 k = 90 진행중...
# <--- k = 90 진행 완료! --->
# 현재 k = 95 진행중...
# <--- k = 95 진행 완료! --->
# 현재 k = 100 진행중...
# <--- k = 100 진행 완료! --->
# 현재 k = 105 진행중...
# <--- k = 105 진행 완료! --->
# 현재 k = 110 진행중...
# <--- k = 110 진행 완료! --->
# ...

# %%
inertias = [model.inertia_ for model in km_per_k]

# %%
# 이너셔 확인
import matplotlib.pyplot as plt
plt.figure(figsize = (10,6))
plt.plot(range(5,155,5), inertias, "bo-", label = "inertia")
plt.xlabel('$K$')
plt.legend()
plt.show()

# %% [markdown]
# #### 엘보지점이 클러스터 150개 내에선 찾기가 어렵다.

# %%
# 실루엣 점수 확인
import numpy as np
from sklearn.metrics import silhouette_score
silhouette_scores = [silhouette_score(x_train_pca, model.labels_) for model in km_per_k]

# 가장 높은 실루엣 점수
best_idx = np.argmax(silhouette_scores)
k_range = range(5,155,5)
# 가장 높은 점수 뽑아내기
best_k = k_range[best_idx]
best_score = silhouette_scores[best_idx]

# 실루엣 점수 시각화
plt.figure(figsize = (10,6))
plt.plot(k_range,silhouette_scores, 'bo-',)
plt.xlabel("$K$", fontsize = 14)
plt.plot(best_k, best_score,'rs') # 's' : pch를 사각형으로 출력 
plt.show()

# %% [markdown]
# #### 최적의 클러스터 개수는 120개로 판단된다.

# %% [markdown]
# 문제: 클러스터를 시각화해보세요. 각 클러스터에 비슷한 얼굴이 들어 있나요?

# %%
best_model = km_per_k[best_idx]

# %%
def plot_faces(faces, label, n_cols = 5) :
    faces = faces.reshape(-1,64,64)
    n_rows = (len(faces) - 1 )//n_cols + 1
    plt.figure(figsize = (n_cols, n_rows * 1.1))
    for index, (face,label) in enumerate(zip(faces, label)) :
        plt.subplot(n_rows, n_cols, index+1)
        plt.imshow(face, cmap = "gray")
        plt.axis("off")
        plt.title(label)
    plt.show()
    
for cluster_id in np.unique(best_model.labels_) :
    print("Cluster", cluster_id)
    in_cluster = best_model.labels_ == cluster_id
    faces = x_train[in_cluster]
    labels = y_train[in_cluster]
    plot_faces(faces, labels)
# Out:
# Cluster 0
# Cluster 1
# Cluster 2
# Cluster 3
# Cluster 4
# Cluster 5
# Cluster 6
# Cluster 7
# Cluster 8
# Cluster 9
# Cluster 10
# Cluster 11
# Cluster 12
# Cluster 13
# Cluster 14
# Cluster 15
# Cluster 16
# Cluster 17
# Cluster 18
# Cluster 19
# Cluster 20
# Cluster 21
# Cluster 22
# Cluster 23
# Cluster 24
# Cluster 25
# Cluster 26
# Cluster 27
# Cluster 28
# Cluster 29
# Cluster 30
# Cluster 31
# Cluster 32
# Cluster 33
# Cluster 34
# Cluster 35
# Cluster 36
# Cluster 37
# Cluster 38
# Cluster 39
# Cluster 40
# Cluster 41
# Cluster 42
# Cluster 43
# Cluster 44
# Cluster 45
# Cluster 46
# Cluster 47
# Cluster 48
# Cluster 49
# Cluster 50
# Cluster 51
# Cluster 52
# Cluster 53
# Cluster 54
# Cluster 55
# Cluster 56
# Cluster 57
# Cluster 58
# Cluster 59
# Cluster 60
# Cluster 61
# Cluster 62
# Cluster 63
# Cluster 64
# Cluster 65
# Cluster 66
# Cluster 67
# Cluster 68
# Cluster 69
# Cluster 70
# Cluster 71
# Cluster 72
# Cluster 73
# Cluster 74
# Cluster 75
# Cluster 76
# ...

# %% [markdown]
# ### 올리베티 얼굴 데이터셋으로 계속해보겠습니다. 사진에 나타난 사람을 예측하는 분류기를 훈련하고 검증 세트에서 평가해보세요.

# %% [markdown]
# ### 문제: 올리베티 얼굴 데이터셋에서 가우시안 혼합 모델을 훈련해보세요. 알고리즘의 속도를 높이기 위해 데이터셋의 차원을 감소시켜야 할 것입니다(예를 들면 분산의 99%를 유지하면서 PCA를 사용합니다).

# %% [markdown]
# ### 문제: 이 모델을 사용해 (sample() 메서드로) 새로운 얼굴을 생성하고 시각화해보세요(PCA를 사용했다면 inverse_transform() 메서드를 사용해야 합니다).

# %% [markdown]
# ### 문제: 일부 차원 축소 기법은 이상치 탐지를 위해서 사용할 수도 있습니다. 예를 들어 올리베티 얼굴 데이터셋을 PCA를 사용해 분산의 99% 유지하도록 축소해보세요. 그다음 각 이미지의 재구성 오차를 계산합니다. 그다음 이전 연습문제에서 만든 수정된 이미지를 선택해 재구성 오차를 확인해보세요. 재구성 오차가 얼마나 커지는지 확인하세요. 재구성 이미지를 출력해보면 이유를 알 수 있습니다. 정상 얼굴을 재구성하기 때문입니다.
#
# 이미 PCA를 사용해 축소된 데이터셋을 가지고 있습니다:
