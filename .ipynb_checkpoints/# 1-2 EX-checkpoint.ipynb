# %% [markdown]
# ### 머신러닝을 어떻게 정의할 수 있나요?
#
# 데이터로부터 학습할 시스템을 만드는 것.

# %% [markdown]
# ### 머신러닝이 도움을 줄 수 있는 문제 유형 네 가지?
#
# 이미지 처리(CNN), 자연어 처리(NLP), 군집(Cluster), 예측(Regression)

# %% [markdown]
# ### 레이블된 훈련 세트란?
#
# - 각 샘플에 정답이 담겨져있는 훈련 세트

# %% [markdown]
# ### 가장 널리 사용되는 지도 학습 작업 두 가지?
#
# 수치를 예측하는 회귀, 스팸인지 아닌지 구분하는 분류

# %% [markdown]
# ### 보편적인 비지도 학습 작업 네 가지는?
#
# 시각화 : 패턴 파악에 용이
#
# 군집 : 그룹화를 통해 분류
#
# 차원 축소 : 데이터의 차원을 줄여 복잡도를 줄임
#
# 연관 규칙 학습 : 대량의 데이터에서 특성간 관계 찾기

# %% [markdown]
# ### 사전 정보가 없는 여러 지형에서 로봇을 걸어가게 하려면 어떤 종류의 머신러닝 알고리즘을 사용할 수 있나요?
#
# 강화 학습으로 환경을 관찰해서 행동하고 그 결과로 보상이나 벌점을 부여한다.

# %% [markdown]
# ### 고객을 여러 그룹으로 분할하려면 어떤 알고리즘을 사용해야 하나요?
#
# 그룹의 기준이 없으면 비지도 학습 기반인 군집 분석을 실시, 그룹의 종류가 무엇인지 안다면 지도학습기반 분류학습을 실시한다.

# %% [markdown]
# ### 스팸 감지의 문제는 지도 학습과 비지도 학습 중 어떤 문제로 볼 수 있나요?
#
# 스팸인지 아닌지를 파악하기 때문에 통상적으로 지도학습 문제에 포함한다.

# %% [markdown]
# ### 온라인 학습 시스템이란?
#
# 배치 학습 시스템 : 데이터를 순차적으로 한 개씩, 미니배치같은 작은 단위로 주입시켜 훈련시키는 시스템
#
# 온라인 학습 시스템 : 연속적으로 데이터를 받고 자율 시스템에 빠르게 적응하여 많은 양의 데이터를 훈련시키는 시스템

# %% [markdown]
# ### 외부 메모리 학습이란?
#
# 대용량의 데이터를 학습할때 사용, 데이터를 미니배치로 나누고 온라인 학습 기법을 사용한다.

# %% [markdown]
# ### 예측을 하기 위해 유사도 측정에 의존하는 학습 알고리즘은?
#
# 유사도 측정에 의존하는 학습 알고리즘은 사례기반학습이다. 새로운 샘플이 주어질시 유사도 측정을 통해 학습된 샘플중 비슷한 것을 찾아 예측에 사용한다.

# %% [markdown]
# ### 모델 파라미터와 학습 알고리즘의 하이퍼파라미터 사이에는 어떤 차이가 있나요?
#
# 모델 파라미터 : 모델을 사용하기전에 정의해야하는 파라미터
#
# 하이퍼 파라미터 : 규제와 같은 학습 모델 알고리즘 자체의 파라미터

# %% [markdown]
# ### 모델 기반 알고리즘이 찾는 것은? 성공을 위해 이 알고리즘이 사용하는 가장 일반적인 전략은 무엇인가? 예측은 어떻게 만드는지?
#
# 새로운 샘플에 대한 일반화를 잘 시키기 위해 모델의 최적값을 찾아야한다. 추가적으로 모델의 복잡도를 줄여 비용을 낮추거나 모델에 규제를 매겨 시스템을 훈련시키도록 한다.

# %% [markdown]
# ### 머신러닝의 주요 도전과제는 무엇인가?
#
# 새로운 샘플에 어떤 알고리즘을 사용하면 좋을지, 해당 모델이 과대,과소 적합인지 특성을 잘 반영했는지를 고려하여 최적의 모델을 찾는것이다.

# %% [markdown]
# ### 모델이 훈련 데이터에서의 성능은 좋지만 새로운 샘플에서의 일반화 성능이 나쁘다면 어떤 문제가 있는 건가? 가능한 해결책 3가지는?
#
# 과대적합일 확률이 높다.
#
# ***
# 1. 데이터를 더 많이 수집한다.
#
# 2. 모델에 규제를 좀 더 추가한다.
#
# 3. 모델을 좀 더 간단히 만들거나 데이터의 이상치를 변환, 제거한다.
# ***

# %% [markdown]
# ### 테스트 세트가 무엇이고 왜 사용하는가?
#
# 훈련세트로 모델을 학습하며 훈련세트로 설계한 모델이 실전에 활용되기 이전에 테스트 세트로 모델이 얼마나 잘 작동하는지 확인하기 위해 사용한다.

# %% [markdown]
# ### 검증 세트의 목적은?
#
# 훈련세트의 일부를 떼어내어 다양한 모델을 시행해보고 가장 성능이 좋은 모델을 검증하고 선택하는 것을 목적으로 한다.
# 이후 가장 좋은 모델의 하이퍼파라미터를 조절한다.

# %% [markdown]
# ### 테스트 세트를 사용해 하이퍼파라미터를 튜닝하면 생기는 문제?
#
# 테스트 세트에 과대적합될 위험이 존재하며 새로운 샘플에 대한 오차를 신뢰하기 어려워진다.
