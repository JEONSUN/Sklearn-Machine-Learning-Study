# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = [[2,81],[4,93],[6,91],[8,97]]

# %%
x = [i[0] for i in data]
y = [i[1] for i in data]
print(x,y)
# Out:
# [2, 4, 6, 8] [81, 93, 91, 97]

# %%
plt.figure(figsize =(8,5))
plt.scatter(x,y)
plt.show()

# %%
x_data = np.array(x)
y_data = np.array(y)

# %%
a= 0 
b= 0

# %%
lr = 0.03
epochs = 2001

# %%
for i in range(epochs) :
    y_pred = a * x_data + b
    error = y_data - y_pred
    a_diff = -(2/len(x_data)) * sum(x_data * (error))
    b_diff = -(2/len(x_data)) * sum(error)
    
    a = a  - lr * a_diff
    b = b - lr * b_diff
    if i % 100 == 0 :
        print("epoch =%.f, 기울기=%.f, 절편=%.f" % (i,a,b))
# Out:
# epoch =0, 기울기=28, 절편=5
# epoch =100, 기울기=7, 절편=51
# epoch =200, 기울기=4, 절편=68
# epoch =300, 기울기=3, 절편=75
# epoch =400, 기울기=3, 절편=77
# epoch =500, 기울기=2, 절편=78
# epoch =600, 기울기=2, 절편=79
# epoch =700, 기울기=2, 절편=79
# epoch =800, 기울기=2, 절편=79
# epoch =900, 기울기=2, 절편=79
# epoch =1000, 기울기=2, 절편=79
# epoch =1100, 기울기=2, 절편=79
# epoch =1200, 기울기=2, 절편=79
# epoch =1300, 기울기=2, 절편=79
# epoch =1400, 기울기=2, 절편=79
# epoch =1500, 기울기=2, 절편=79
# epoch =1600, 기울기=2, 절편=79
# epoch =1700, 기울기=2, 절편=79
# epoch =1800, 기울기=2, 절편=79
# epoch =1900, 기울기=2, 절편=79
# epoch =2000, 기울기=2, 절편=79

# %%
y_pred = a * x_data + b
plt.scatter(x,y)
plt.plot([min(x_data), max(x_data)],[min(y_pred), max(y_pred)])
plt.show()

# %%
from mpl_toolkits import mplot3d

# %%
x1 = [2,5,6,8,10,12,14]
x2 = [1,3,4,5,6,8,10]
y = [11,45,68,90,100,111,123]

# %%
ax = plt.axes(projection = '3d')
ax.set_xlabel('study_hours')
ax.set_ylabel('private_class')
ax.set_zlabel('Score')
ax.scatter(x1,x2,y)
plt.show()

# %% [markdown]
# ### Logistic

# %%
data = [[2,0],[4,0],[6,0],[8,1],[10,1],[12,1],[14,1]]
data
# Out:
# [[2, 0], [4, 0], [6, 0], [8, 1], [10, 1], [12, 1], [14, 1]]

# %%
x_data = [i[0] for i in data]
y_data = [i[1] for i in data]

# %%
x_data = np.array(x_data).reshape(-1,1)
y_data = np.array(y_data)

# %%
from sklearn.linear_model import LinearRegression

# %%
linr = LinearRegression()

# %%
linr.fit(x_data,y_data)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
linr.coef_
# Out:
# array([0.10714286])

# %%
linr.intercept_
# Out:
# -0.2857142857142855

# %%
list(x_data.flatten())
# Out:
# [2, 4, 6, 8, 10, 12, 14]

# %%
mod = []

for i in list(x_data.flatten()) :
    mod.append(-0.29 + (0.11*i))

# %%
mod
# Out:
# [-0.06999999999999998,
#  0.15000000000000002,
#  0.37000000000000005,
#  0.5900000000000001,
#  0.81,
#  1.03,
#  1.25]

# %%
plt.scatter(x_data,y_data)
plt.plot(x_data,mod)
plt.show()

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(x_data,y_data)
plt.xlim(0,15)
plt.ylim(-.1,1.1)
# Out:
# (-0.1, 1.1)

# %%
a = 0
b = 0
lr = 0.05

# %%
def sigmoid(x) :
    return 1 / (1 + np.e ** (-x))

# %%
import numpy as np

# %%
for i in range(2001) :
    for x_data, y_data in data :
        a_diff = x_data * (sigmoid(a * x_data + b) - y_data)
        b_diff = sigmoid(a * x_data + b) - y_data
        a = a-lr*a_diff
        b = b-lr*b_diff
        if i % 1000 == 0 :
            print("epoch=%.f,기울기=%.04f,절편=%.04f" % (i, a, b))
# Out:
# epoch=0,기울기=-0.0500,절편=-0.0250
# epoch=0,기울기=-0.1388,절편=-0.0472
# epoch=0,기울기=-0.2268,절편=-0.0619
# epoch=0,기울기=0.1201,절편=-0.0185
# epoch=0,기울기=0.2374,절편=-0.0068
# epoch=0,기울기=0.2705,절편=-0.0040
# epoch=0,기울기=0.2860,절편=-0.0029
# epoch=1000,기울기=1.4978,절편=-9.9401
# epoch=1000,기울기=1.4940,절편=-9.9411
# epoch=1000,기울기=1.4120,절편=-9.9547
# epoch=1000,기울기=1.4949,절편=-9.9444
# epoch=1000,기울기=1.4982,절편=-9.9440
# epoch=1000,기울기=1.4984,절편=-9.9440
# epoch=1000,기울기=1.4985,절편=-9.9440
# epoch=2000,기울기=1.9065,절편=-12.9489
# epoch=2000,기울기=1.9055,절편=-12.9491
# epoch=2000,기울기=1.8515,절편=-12.9581
# epoch=2000,기울기=1.9057,절편=-12.9514
# epoch=2000,기울기=1.9068,절편=-12.9513
# epoch=2000,기울기=1.9068,절편=-12.9513
# epoch=2000,기울기=1.9068,절편=-12.9513

# %%
plt.scatter(x_data, y_data)
plt.xlim(0, 15)
plt.ylim(-.1,1.1)
x_range = (np.arange(0,15,0.1))
plt.plot(np.arange(0,15,0.1), np.array([sigmoid(a*x + b)
                                       for x in x_range]))
plt.show()

# %% [markdown]
# ### XOR 게이트
#
# x1, x2중에 1이 하나만 있는 경우 색출하는 다층 퍼셉트론 설계
#
#
# #### NAND(Negative And) 게이트
#
# - x1, x2가 모두 1일 때 0을 출력하고 하나라도 0이 아니면 1을 출력
#
# #### OR 게이트
#
# - x1, x2가 하나라도 1일 경우 1을 출력
#
# #### AND 게이트
#
# - x1, x2가 모두 1일 경우 1을 출력
#
# #### XOR 게이트
#
# - x1, x2중 하나만 1일 경우 1을 출력

# %%
import numpy as np

# %%
# 가중치와 바이어스 설정
w11 = np.array([-2,-2])
w12 = np.array([2,2])
w2 = np.array([1,1])
b1 = 3
b2 = -1
b3 = -1

# %%
# 퍼셉트론 함수 생성
def MLP(x,w,b) :
    y = np.sum(w * x) + b
    if y <= 0 :
        return 0
    else :
        return 1

# %%
# nand 게이트
def NAND(x1, x2) :
    return MLP(np.array([x1,x2]),w11, b1)

# %%
# or 게이트
def OR(x1, x2) : 
    return MLP(np.array([x1,x2]),w12,b2)

# %%
# and 게이트
def AND(x1, x2) : 
    return MLP(np.array([x1,x2]),w2 , b3)

# %%
# xor 게이트
def XOR(x1, x2) :
    return AND(NAND(x1,x2),OR(x1,x2))

# %%
if __name__ == '__main__' :
    for x in [(0,0),(1,0),(0,1),(1,1)] :
        y = XOR(x[0],x[1])
        print("입력 값 :" + str(x) + "출력 값 :" + str(y))
# Out:
# 입력 값 :(0, 0)출력 값 :0
# 입력 값 :(1, 0)출력 값 :1
# 입력 값 :(0, 1)출력 값 :1
# 입력 값 :(1, 1)출력 값 :0

# %% [markdown]
# 입력값($x_1,x_2$)이 0,0인 경우
#
# $node(n_1)$ = $function(x_1w_11 + x_2w_21 + b_1)$ -> $function(0*(-2)+0*(-2)+3)$ $== 3$ $return MLP==> 1$ <br>
# $node(n_2)$ = $function(x_1w_21 + x_2w_21 + b_1)$ -> $function(0*(2)+0*(2)-1)$ $== 1$ $return MLP==> 0$
#
# $y_out$ =$function(n_1w_31 + n_2w_32 + b_3)$ -> $function(1*1 + 0*1 - 1)$ $== 0$ $==> 0$

# %%
m = 100
x  = 6 * np.random.rand(m, 1) - 3
y = 0.5 * x**2 - x + 2 + np.random.randn(m,1)

# %%
print(x)
# Out:
# [[-1.16031717]
#  [ 2.54099944]
#  [-2.90025645]
#  [ 1.62420627]
#  [ 2.7557056 ]
#  [ 0.44519991]
#  [-0.68295028]
#  [-1.44156054]
#  [-0.91705048]
#  [ 1.18854455]
#  [ 0.51541522]
#  [-1.16119784]
#  [-0.88755499]
#  [-1.83368413]
#  [-0.51287023]
#  [ 0.93359602]
#  [ 2.325081  ]
#  [-1.14268961]
#  [-0.58710544]
#  [-1.4681518 ]
#  [ 1.24069247]
#  [-0.54675773]
#  [-0.87986457]
#  [ 2.66983976]
#  [ 1.90781348]
#  [ 0.93012559]
#  [ 0.85713728]
#  [ 1.62384398]
#  [ 0.28144247]
#  [-1.78911745]
#  [ 1.50611212]
#  [-2.2949413 ]
#  [-0.56879059]
#  [ 1.54117977]
#  [ 2.96831252]
#  [ 1.88674134]
#  [ 0.10013726]
#  [-1.38664232]
#  [-1.4303629 ]
#  [ 2.05444532]
#  [-1.19639155]
#  [-0.54341533]
#  [-1.84135925]
#  [ 2.0566606 ]
#  [ 1.08199653]
#  [-1.67025944]
#  [ 1.5569711 ]
#  [ 0.6409662 ]
#  [-0.30056372]
#  [ 2.04821187]
#  [-1.85412531]
#  [-2.92224202]
#  [-0.05210022]
#  [ 2.17700888]
#  [ 1.82089448]
#  [-1.53283984]
#  [-0.52248244]
#  [-2.64730222]
# ...

# %%
plt.scatter(x,y)
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_features = PolynomialFeatures(degree = 2, include_bias = False)

# %%
x_poly = poly_features.fit_transform(x)

# %%
x_poly
# Out:
# array([[-1.16031717e+00,  1.34633593e+00],
#        [ 2.54099944e+00,  6.45667813e+00],
#        [-2.90025645e+00,  8.41148749e+00],
#        [ 1.62420627e+00,  2.63804602e+00],
#        [ 2.75570560e+00,  7.59391334e+00],
#        [ 4.45199913e-01,  1.98202963e-01],
#        [-6.82950285e-01,  4.66421091e-01],
#        [-1.44156054e+00,  2.07809680e+00],
#        [-9.17050475e-01,  8.40981574e-01],
#        [ 1.18854455e+00,  1.41263815e+00],
#        [ 5.15415223e-01,  2.65652852e-01],
#        [-1.16119784e+00,  1.34838043e+00],
#        [-8.87554991e-01,  7.87753862e-01],
#        [-1.83368413e+00,  3.36239749e+00],
#        [-5.12870228e-01,  2.63035871e-01],
#        [ 9.33596015e-01,  8.71601519e-01],
#        [ 2.32508100e+00,  5.40600166e+00],
#        [-1.14268961e+00,  1.30573955e+00],
#        [-5.87105439e-01,  3.44692796e-01],
#        [-1.46815180e+00,  2.15546970e+00],
#        [ 1.24069247e+00,  1.53931781e+00],
#        [-5.46757732e-01,  2.98944018e-01],
# ...
